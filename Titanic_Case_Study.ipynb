# %% [markdown]
# # Import the Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the CSV File

# %%
df = pd.read_csv(r"C:\Users\jangi\Downloads\Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Check the data

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Check the Null Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Conculsion
#
# - missing values in the columns Age , Cabin , Embarked.
# - more then 70% values are missing in the cabin, so we will drop this column.
# - few columns has inappropriate data types.

# %%
df.drop(columns = ["Cabin"], inplace = True)

# %% [markdown]
# ## Fill the null Values

# %%
df["Age"].fillna(df["Age"].mean(), inplace = True)

# %%
df["Age"].isna().sum()
# Out:
# 0

# %% [markdown]
# # Check the type of Embarked column of null values

# %%
df["Embarked"].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Find the most Appear values in embarked column

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# # Fill the null value

# %%
df["Embarked"].fillna("S", inplace = True)

# %%
df["Embarked"].isna().sum()
# Out:
# 0

# %% [markdown]
# # Change the data type in the column

# %%
df["Survived"] = df["Survived"].astype("category")
df["Pclass"] = df["Pclass"].astype("category")
df["Sex"] = df["Sex"].astype("category")
df["Embarked"] = df["Embarked"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(2), int64(3), object(2)
# memory usage: 52.8+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   13.002015    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.699118    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize = (5,5), dpi = 100)
ax = sns.countplot(x = "Survived",data = df)

for i in ax.containers:
    ax.bar_label(i)

death_percentage = round((df["Survived"].value_counts().values[0]/891)*100)

print("out of 891 {} are death".format(death_percentage))
# Out:
# out of 891 62 are death

# %%
plt.figure(figsize = (5,5), dpi = 100)
ax = sns.countplot(x = "Pclass",data = df)

for i in ax.containers:
    ax.bar_label(i)
    
print((df["Pclass"].value_counts()/891)*100)
# Out:
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: Pclass, dtype: float64

# %%
plt.figure(figsize = (5,5), dpi = 100)
ax = sns.countplot(x = "Sex",data = df)

for i in ax.containers:
    ax.bar_label(i)
    
print((df["Sex"].value_counts()/891)*100)
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64

# %%
plt.figure(figsize = (5,5), dpi = 100)
ax = sns.countplot(x = "SibSp",data = df)

for i in ax.containers:
    ax.bar_label(i)
    
print((df["SibSp"].value_counts()/891)*100)
# Out:
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: SibSp, dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Check the Outliers of Age Column

# %% [markdown]
# # IQR Method Function

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: >

# %%
df.Age.describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# # IQR method For Age

# %%
def outlier(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 1.5 * iqr
    lower_bound = q1 - 1.5 * iqr
    return data.clip(upper_bound,lower_bound)

# %%
df["New_Age"] = outlier(df.Age)

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  New_Age
# 0      0         A/5 21171   7.2500        S     22.0
# 1      0          PC 17599  71.2833        C     38.0
# 2      0  STON/O2. 3101282   7.9250        S     26.0
# 3      0            113803  53.1000        S     35.0
# 4      0            373450   8.0500        S     35.0

# %%
df[["Age","New_Age"]].describe()
# Out:
#               Age     New_Age
# count  891.000000  891.000000
# mean    29.699118   29.376817
# std     13.002015   12.062035
# min      0.420000    2.500000
# 25%     22.000000   22.000000
# 50%     29.699118   29.699118
# 75%     35.000000   35.000000
# max     80.000000   54.500000

# %%
sns.boxplot(y="New_Age" , data=df )
# Out:
# <Axes: ylabel='New_Age'>

# %% [markdown]
# # Check the Outliers of Age Column

# %%
sns.boxplot(df["Fare"])
# Out:
# <Axes: >

# %% [markdown]
# # IQR method For Fare

# %%
df["New_Fare"] = outlier(df.Fare)

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  New_Age  New_Fare
# 0      0         A/5 21171   7.2500        S     22.0    7.2500
# 1      0          PC 17599  71.2833        C     38.0   65.6344
# 2      0  STON/O2. 3101282   7.9250        S     26.0    7.9250
# 3      0            113803  53.1000        S     35.0   53.1000
# ...

# %%
df[["Fare","New_Fare"]].describe()
# Out:
#              Fare    New_Fare
# count  891.000000  891.000000
# mean    32.204208   24.046813
# std     49.693429   20.481625
# min      0.000000    0.000000
# 25%      7.910400    7.910400
# 50%     14.454200   14.454200
# 75%     31.000000   31.000000
# max    512.329200   65.634400

# %%
sns.boxplot(y="New_Fare" , data=df )
# Out:
# <Axes: ylabel='New_Fare'>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.countplot(x = df["Survived"], hue=df["Pclass"] )

pd.crosstab(df["Survived"],df["Pclass"]).apply(lambda r : round((r/r.sum())*100 ,1),axis = 1)
# Out:
# Pclass       1     2     3
# Survived
# 0         14.6  17.7  67.8
# 1         39.8  25.4  34.8

# %%
sns.countplot(x = df["Survived"], hue=df["Embarked"] )

pd.crosstab(df["Survived"],df["Embarked"]).apply(lambda r : round((r/r.sum())*100 ,1),axis = 1)
# Out:
# Embarked     C    Q     S
# Survived
# 0         13.7  8.6  77.8
# 1         27.2  8.8  64.0

# %%
plt.figure(figsize=(15,6))
sns.displot(df[df["Survived"]==0]["Age"])
sns.displot(df[df["Survived"]==0]["Age"])

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  New_Age  New_Fare
# 0      0         A/5 21171   7.2500        S     22.0    7.2500
# 1      0          PC 17599  71.2833        C     38.0   65.6344
# 2      0  STON/O2. 3101282   7.9250        S     26.0    7.9250
# 3      0            113803  53.1000        S     35.0   53.1000
# ...
